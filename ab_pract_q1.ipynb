# %% [markdown]
# DAV practical list q1

# %%
original_dict = {'boys':[72, 68, 70, 69, 74], 'girls':[63, 65, 69, 62, 61]}
empty_list = []
for i in range(len(original_dict['boys'])):
  empty_list.append({'boys':original_dict['boys'][i],'girls':original_dict['girls'][i]})
print(empty_list)
# Out:
# [{'boys': 72, 'girls': 63}, {'boys': 68, 'girls': 65}, {'boys': 70, 'girls': 69}, {'boys': 69, 'girls': 62}, {'boys': 74, 'girls': 61}]

# %%
import numpy as np

dictionary = {'boys':[72, 68, 70, 69, 74], 'Girls':[63, 65, 69, 62, 61]}
EmptyList = []
for i in range(len(dictionary['boys'])):
  EmptyList.append({'boys':dictionary['boys'][i], 'Girls':dictionary['Girls'][i]})
print(EmptyList)
# Out:
# [{'boys': 72, 'Girls': 63}, {'boys': 68, 'Girls': 65}, {'boys': 70, 'Girls': 69}, {'boys': 69, 'Girls': 62}, {'boys': 74, 'Girls': 61}]
