# %%
#                                        Question -4

# %%
import numpy as np
import pandas as pd

# %%
#to unmount google drive

#from google.colab import drive
#drive.flush_and_unmount()

# to mount google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#adding attendence files

df=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Attendence1.xlsx")
df1=pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Attendence2.xlsx")

# %%
df
# Out:
#        NAME TIME OF JOINING  DURATION (IN MIN)
# 0    Chetan        11:15:00                 40
# 1    Chetna        11:00:00                 50
# 2    Dhwani        11:02:00                 30
# 3  Himanshi        11:00:00                 40
# 4   konicca        11:10:00                 50

# %%
df1
# Out:
#         NAME TIME OF JOINING  DURATION (IN MIN)
# 0     Amisha        11:15:00                 40
# 1  Ayush Jha        11:02:00                 30
# 2     Chetna        11:00:00                 50
# 3   Himanshi        11:00:00                 40
# 4     khushi        11:10:00                 50

# %%
df.parse_dates = ("Time of joining")
df
# Out:
#        NAME TIME OF JOINING  DURATION (IN MIN)
# 0    Chetan        11:15:00                 40
# 1    Chetna        11:00:00                 50
# 2    Dhwani        11:02:00                 30
# 3  Himanshi        11:00:00                 40
# 4   konicca        11:10:00                 50

# %%
df1.parse_dates = ("Time of joining")
df1
# Out:
#         NAME TIME OF JOINING  DURATION (IN MIN)
# 0     Amisha        11:15:00                 40
# 1  Ayush Jha        11:02:00                 30
# 2     Chetna        11:00:00                 50
# 3   Himanshi        11:00:00                 40
# 4     khushi        11:10:00                 50

# %%
                #part a

df.merge(df1, how='inner', on='NAME')
# Out:
#        NAME TIME OF JOINING_x  DURATION (IN MIN)_x TIME OF JOINING_y  \
# 0    Chetna          11:00:00                   50          11:00:00
# 1  Himanshi          11:00:00                   40          11:00:00
#
#    DURATION (IN MIN)_y
# 0                   50
# 1                   40

# %%
df
# Out:
#        NAME TIME OF JOINING  DURATION (IN MIN)
# 0    Chetan        11:15:00                 40
# 1    Chetna        11:00:00                 50
# 2    Dhwani        11:02:00                 30
# 3  Himanshi        11:00:00                 40
# 4   konicca        11:10:00                 50

# %%
                  #part - b
df.merge(df1,how="outer")
# Out:
#         NAME TIME OF JOINING  DURATION (IN MIN)
# 0     Chetan        11:15:00                 40
# 1     Chetna        11:00:00                 50
# 2     Dhwani        11:02:00                 30
# 3   Himanshi        11:00:00                 40
# 4    konicca        11:10:00                 50
# 5     Amisha        11:15:00                 40
# 6  Ayush Jha        11:02:00                 30
# 7     khushi        11:10:00                 50

# %%
                  #part -c
a=pd.concat([df,df1],ignore_index=True)
a
# Out:
#         NAME TIME OF JOINING  DURATION (IN MIN)
# 0     Chetan        11:15:00                 40
# 1     Chetna        11:00:00                 50
# 2     Dhwani        11:02:00                 30
# 3   Himanshi        11:00:00                 40
# 4    konicca        11:10:00                 50
# 5     Amisha        11:15:00                 40
# 6  Ayush Jha        11:02:00                 30
# 7     Chetna        11:00:00                 50
# 8   Himanshi        11:00:00                 40
# 9     khushi        11:10:00                 50

# %%
len(a)
# Out:
# 10

# %%
                       #part -d
b=df.merge(df1,how="outer")
b
# Out:
#         NAME TIME OF JOINING  DURATION (IN MIN)
# 0     Chetan        11:15:00                 40
# 1     Chetna        11:00:00                 50
# 2     Dhwani        11:02:00                 30
# 3   Himanshi        11:00:00                 40
# 4    konicca        11:10:00                 50
# 5     Amisha        11:15:00                 40
# 6  Ayush Jha        11:02:00                 30
# 7     khushi        11:10:00                 50

# %%
c=b.set_index(keys=["NAME","DURATION (IN MIN)"])
c
# Out:
#                             TIME OF JOINING
# NAME      DURATION (IN MIN)
# Chetan    40                       11:15:00
# Chetna    50                       11:00:00
# Dhwani    30                       11:02:00
# Himanshi  40                       11:00:00
# konicca   50                       11:10:00
# Amisha    40                       11:15:00
# Ayush Jha 30                       11:02:00
# khushi    50                       11:10:00

# %%
c.describe()
# Out:
#        TIME OF JOINING
# count                8
# unique               4
# top           11:15:00
# freq                 2
